# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
# getting some networking issue, reading static file instead
# source: https://www.cantoneseclass101.com/chinese-radicals/
page_content = open('../data/cantonese/radicals.html', 'rb')

# %%
# parse table
soup = BeautifulSoup(page_content, 'html.parser')
radical_table = soup.html.find_all('table', id='radical-table')[0]

# get data entries
rows = radical_table.tbody.find_all('tr')
header = rows[0]
entries = rows[1:]

# %%
# collect radical data
radical_data = []
stroke_count = 0

for entry in entries:
    # if the entry has the stroke count field
    if len(entry) == 13:
        stroke_count = int(entry.find_all('td')[0].find('span').text)
        radical_data.append(
            {
                'stroke_count': stroke_count,
                'cantonese': entry.find_all('td')[1].text.strip()[0],
                'variants': list(filter(lambda x: x.strip() != '',
                    list(entry.find_all('td')[2].text.strip()) + list(entry.find_all('td')[1].text.strip()[1:]))),
                'english': entry.find_all('td')[3].text,
                'jyutping': entry.find_all('td')[4].text    
            }
        )
        
    # the entry doesn't have the stroke count field
    else:
        radical_data.append(
            {
                'stroke_count': stroke_count,
                'cantonese': entry.find_all('td')[0].text.strip()[0],
                'variants': list(filter(lambda x: x.strip() != '',
                    list(entry.find_all('td')[1].text.strip()) + list(entry.find_all('td')[0].text.strip()[1:]))),
                'english': entry.find_all('td')[2].text,
                'jyutping': entry.find_all('td')[3].text
            }
        )

# %%
radical_data
# Out:
# [{'stroke_count': 1,
#   'cantonese': '一',
#   'variants': [],
#   'english': 'one',
#   'jyutping': 'jat1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jat1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/一.gif'},
#  {'stroke_count': 1,
#   'cantonese': '丨',
#   'variants': [],
#   'english': 'line',
#   'jyutping': 'gwan2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwan2.mp3'},
#  {'stroke_count': 1,
#   'cantonese': '丶',
#   'variants': [],
#   'english': 'dot',
#   'jyutping': 'zyu2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zyu2.mp3'},
#  {'stroke_count': 1,
#   'cantonese': '丿',
#   'variants': ['乀', '乁'],
#   'english': 'slash',
#   'jyutping': 'pit3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/pit3.mp3'},
#  {'stroke_count': 1,
#   'cantonese': '乙',
#   'variants': ['乚', '乛'],
#   'english': 'second',
#   'jyutping': 'jyut6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyut6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/乙.gif'},
#  {'stroke_count': 1,
#   'cantonese': '亅',
#   'variants': [],
#   'english': 'hook',
#   'jyutping': 'kyut3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/kyut3.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '二',
#   'variants': [],
#   'english': 'two',
#   'jyutping': 'ji6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ji6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/二.gif'},
#  {'stroke_count': 2,
#   'cantonese': '亠',
#   'variants': [],
#   'english': 'lid',
#   'jyutping': 'tau4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/tau4.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '亻',
#   'variants': ['人'],
#   'english': 'person',
#   'jyutping': 'jan4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jan4.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '儿',
#   'variants': [],
#   'english': 'legs',
#   'jyutping': 'jan4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jan4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/儿.gif'},
#  {'stroke_count': 2,
#   'cantonese': '入',
#   'variants': [],
#   'english': 'enter',
#   'jyutping': 'jap6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jap6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/入.gif'},
#  {'stroke_count': 2,
#   'cantonese': '八',
#   'variants': ['丷'],
#   'english': 'eight',
#   'jyutping': 'baat3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/baat3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/八.gif'},
#  {'stroke_count': 2,
#   'cantonese': '冂',
#   'variants': [],
#   'english': 'down box',
#   'jyutping': 'gwing2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwing2.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '冖',
#   'variants': [],
#   'english': 'cover',
#   'jyutping': 'mik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mik6.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '冫',
#   'variants': [],
#   'english': 'ice',
#   'jyutping': 'bing1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bing1.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '几',
#   'variants': [],
#   'english': 'table',
#   'jyutping': 'gei1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gei1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/几.gif'},
#  {'stroke_count': 2,
#   'cantonese': '凵',
#   'variants': [],
#   'english': 'open box',
#   'jyutping': 'ham3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ham3.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '刀',
#   'variants': ['刂'],
#   'english': 'knife',
#   'jyutping': 'dou1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/dou1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/刀.gif'},
#  {'stroke_count': 2,
#   'cantonese': '力',
#   'variants': [],
#   'english': 'power',
#   'jyutping': 'lik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/lik6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/力.gif'},
#  {'stroke_count': 2,
#   'cantonese': '勹',
#   'variants': [],
#   'english': 'wrap',
#   'jyutping': 'paau1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/paau1.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '匕',
#   'variants': [],
#   'english': 'ladle',
#   'jyutping': 'bei2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bei2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/匕.gif'},
#  {'stroke_count': 2,
#   'cantonese': '匚',
#   'variants': [],
#   'english': 'right open box',
#   'jyutping': 'fong1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fong1.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '匸',
#   'variants': [],
#   'english': 'hiding enclosure',
#   'jyutping': 'hai5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hai5.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '十',
#   'variants': [],
#   'english': 'ten',
#   'jyutping': 'sap6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sap6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/十.gif'},
#  {'stroke_count': 2,
#   'cantonese': '卜',
#   'variants': [],
#   'english': 'divination',
#   'jyutping': 'buk1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/buk1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/卜.gif'},
#  {'stroke_count': 2,
#   'cantonese': '卩',
#   'variants': [],
#   'english': 'seal',
#   'jyutping': 'zit3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zit3.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '厂',
#   'variants': [],
#   'english': 'cliff',
#   'jyutping': 'hon3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hon3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/厂.gif'},
#  {'stroke_count': 2,
#   'cantonese': '厶',
#   'variants': [],
#   'english': 'private',
#   'jyutping': 'si1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/si1.mp3'},
#  {'stroke_count': 2,
#   'cantonese': '又',
#   'variants': [],
#   'english': 'again',
#   'jyutping': 'jau6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jau6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/又.gif'},
#  {'stroke_count': 3,
#   'cantonese': '口',
#   'variants': [],
#   'english': 'mouth',
#   'jyutping': 'hau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/口.gif'},
#  {'stroke_count': 3,
#   'cantonese': '囗',
#   'variants': [],
#   'english': 'enclosure',
#   'jyutping': 'wai4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wai4.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '土',
#   'variants': [],
#   'english': 'earth',
#   'jyutping': 'tou2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/tou2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/土.gif'},
#  {'stroke_count': 3,
#   'cantonese': '士',
#   'variants': [],
#   'english': 'scholar',
#   'jyutping': 'si6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/si6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/士.gif'},
#  {'stroke_count': 3,
#   'cantonese': '夂',
#   'variants': [],
#   'english': 'go',
#   'jyutping': 'zi2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi2.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '夊',
#   'variants': [],
#   'english': 'go slowly',
#   'jyutping': 'seoi1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/seoi1.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '夕',
#   'variants': [],
#   'english': 'night',
#   'jyutping': 'zik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zik6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/夕.gif'},
#  {'stroke_count': 3,
#   'cantonese': '大',
#   'variants': [],
#   'english': 'big',
#   'jyutping': 'daai6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/daai6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/大.gif'},
#  {'stroke_count': 3,
#   'cantonese': '女',
#   'variants': [],
#   'english': 'woman',
#   'jyutping': 'neoi5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/neoi5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/女.gif'},
#  {'stroke_count': 3,
#   'cantonese': '子',
#   'variants': [],
#   'english': 'child',
#   'jyutping': 'zi2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/子.gif'},
#  {'stroke_count': 3,
#   'cantonese': '宀',
#   'variants': [],
#   'english': 'roof',
#   'jyutping': 'min4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/min4.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '寸',
#   'variants': [],
#   'english': 'inch',
#   'jyutping': 'cyun3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cyun3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/寸.gif'},
#  {'stroke_count': 3,
#   'cantonese': '小',
#   'variants': [],
#   'english': 'small',
#   'jyutping': 'siu2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/siu2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/小.gif'},
#  {'stroke_count': 3,
#   'cantonese': '尢',
#   'variants': [],
#   'english': 'lame',
#   'jyutping': 'wong1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wong1.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '尸',
#   'variants': [],
#   'english': 'corpse',
#   'jyutping': 'si1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/si1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/尸.gif'},
#  {'stroke_count': 3,
#   'cantonese': '屮',
#   'variants': [],
#   'english': 'sprout',
#   'jyutping': 'cit3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cit3.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '山',
#   'variants': [],
#   'english': 'mountain',
#   'jyutping': 'saan1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/saan1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/山.gif'},
#  {'stroke_count': 3,
#   'cantonese': '巛',
#   'variants': ['巜'],
#   'english': 'river',
#   'jyutping': 'cyun1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cyun1.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '工',
#   'variants': [],
#   'english': 'work',
#   'jyutping': 'gung1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gung1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/工.gif'},
#  {'stroke_count': 3,
#   'cantonese': '己',
#   'variants': [],
#   'english': 'oneself',
#   'jyutping': 'gei2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gei2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/己.gif'},
#  {'stroke_count': 3,
#   'cantonese': '巾',
#   'variants': [],
#   'english': 'towel',
#   'jyutping': 'gan1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gan1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/巾.gif'},
#  {'stroke_count': 3,
#   'cantonese': '干',
#   'variants': [],
#   'english': 'dry',
#   'jyutping': 'gon1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gon1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/干.gif'},
#  {'stroke_count': 3,
#   'cantonese': '幺',
#   'variants': [],
#   'english': 'thread',
#   'jyutping': 'jiu1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jiu1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/幺.gif'},
#  {'stroke_count': 3,
#   'cantonese': '广',
#   'variants': [],
#   'english': 'shelter',
#   'jyutping': 'jim5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jim5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/广.gif'},
#  {'stroke_count': 3,
#   'cantonese': '廴',
#   'variants': [],
#   'english': 'stride',
#   'jyutping': 'jan5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jan5.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '廾',
#   'variants': [],
#   'english': 'hands joined',
#   'jyutping': 'gung2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gung2.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '弋',
#   'variants': [],
#   'english': 'shoot with a bow',
#   'jyutping': 'jik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jik6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/弋.gif'},
#  {'stroke_count': 3,
#   'cantonese': '弓',
#   'variants': [],
#   'english': 'bow',
#   'jyutping': 'gung1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gung1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/弓.gif'},
#  {'stroke_count': 3,
#   'cantonese': '彐',
#   'variants': ['彑'],
#   'english': 'snout',
#   'jyutping': 'gai3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gai3.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '彡',
#   'variants': [],
#   'english': 'hair',
#   'jyutping': 'saam1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/saam1.mp3'},
#  {'stroke_count': 3,
#   'cantonese': '彳',
#   'variants': [],
#   'english': 'step',
#   'jyutping': 'cik1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cik1.mp3'},
#  {'stroke_count': 4,
#   'cantonese': '心',
#   'variants': ['忄'],
#   'english': 'heart',
#   'jyutping': 'sam1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sam1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/心.gif'},
#  {'stroke_count': 4,
#   'cantonese': '戈',
#   'variants': [],
#   'english': 'spear',
#   'jyutping': 'gwo1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwo1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/戈.gif'},
#  {'stroke_count': 4,
#   'cantonese': '户',
#   'variants': ['戶'],
#   'english': 'door',
#   'jyutping': 'wu6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wu6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/户.gif'},
#  {'stroke_count': 4,
#   'cantonese': '手',
#   'variants': ['扌'],
#   'english': 'hand',
#   'jyutping': 'sau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/手.gif'},
#  {'stroke_count': 4,
#   'cantonese': '支',
#   'variants': [],
#   'english': 'branch',
#   'jyutping': 'zi1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/支.gif'},
#  {'stroke_count': 4,
#   'cantonese': '攴',
#   'variants': ['攵'],
#   'english': 'rap',
#   'jyutping': 'pok3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/pok3.mp3'},
#  {'stroke_count': 4,
#   'cantonese': '文',
#   'variants': [],
#   'english': 'script',
#   'jyutping': 'man4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/man4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/文.gif'},
#  {'stroke_count': 4,
#   'cantonese': '斗',
#   'variants': [],
#   'english': 'dipper',
#   'jyutping': 'dau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/dau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/斗.gif'},
#  {'stroke_count': 4,
#   'cantonese': '斤',
#   'variants': [],
#   'english': 'axe',
#   'jyutping': 'gan1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gan1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/斤.gif'},
#  {'stroke_count': 4,
#   'cantonese': '方',
#   'variants': [],
#   'english': 'square',
#   'jyutping': 'fong1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fong1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/方.gif'},
#  {'stroke_count': 4,
#   'cantonese': '无',
#   'variants': [],
#   'english': 'not',
#   'jyutping': 'mou4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mou4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/无.gif'},
#  {'stroke_count': 4,
#   'cantonese': '日',
#   'variants': [],
#   'english': 'sun',
#   'jyutping': 'jat6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jat6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/日.gif'},
#  {'stroke_count': 4,
#   'cantonese': '曰',
#   'variants': [],
#   'english': 'say',
#   'jyutping': 'joek6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/joek6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/曰.gif'},
#  {'stroke_count': 4,
#   'cantonese': '月',
#   'variants': [],
#   'english': 'moon',
#   'jyutping': 'jyut6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyut6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/月.gif'},
#  {'stroke_count': 4,
#   'cantonese': '木',
#   'variants': [],
#   'english': 'tree',
#   'jyutping': 'muk6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/muk6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/木.gif'},
#  {'stroke_count': 4,
#   'cantonese': '欠',
#   'variants': [],
#   'english': 'lack',
#   'jyutping': 'him3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/him3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/欠.gif'},
#  {'stroke_count': 4,
#   'cantonese': '止',
#   'variants': [],
#   'english': 'stop',
#   'jyutping': 'zi2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/止.gif'},
#  {'stroke_count': 4,
#   'cantonese': '歹',
#   'variants': [],
#   'english': 'death',
#   'jyutping': 'aat3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/aat3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/歹.gif'},
#  {'stroke_count': 4,
#   'cantonese': '殳',
#   'variants': [],
#   'english': 'weapon',
#   'jyutping': 'syu4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/syu4.mp3'},
#  {'stroke_count': 4,
#   'cantonese': '毋',
#   'variants': ['母'],
#   'english': 'mother',
#   'jyutping': 'mou4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mou4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/毋.gif'},
#  {'stroke_count': 4,
#   'cantonese': '比',
#   'variants': [],
#   'english': 'compare',
#   'jyutping': 'bei2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bei2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/比.gif'},
#  {'stroke_count': 4,
#   'cantonese': '毛',
#   'variants': [],
#   'english': 'fur',
#   'jyutping': 'mou4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mou4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/毛.gif'},
#  {'stroke_count': 4,
#   'cantonese': '氏',
#   'variants': [],
#   'english': 'clan',
#   'jyutping': 'si6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/si6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/氏.gif'},
#  {'stroke_count': 4,
#   'cantonese': '气',
#   'variants': [],
#   'english': 'steam',
#   'jyutping': 'hei3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hei3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/气.gif'},
#  {'stroke_count': 4,
#   'cantonese': '水',
#   'variants': ['氵'],
#   'english': 'water',
#   'jyutping': 'seoi2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/seoi2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/水.gif'},
#  {'stroke_count': 4,
#   'cantonese': '火',
#   'variants': ['灬'],
#   'english': 'fire',
#   'jyutping': 'fo2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fo2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/火.gif'},
#  {'stroke_count': 4,
#   'cantonese': '爪',
#   'variants': ['爫'],
#   'english': 'claw',
#   'jyutping': 'zaau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zaau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/爪.gif'},
#  {'stroke_count': 4,
#   'cantonese': '父',
#   'variants': [],
#   'english': 'father',
#   'jyutping': 'fu6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fu6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/父.gif'},
#  {'stroke_count': 4,
#   'cantonese': '爻',
#   'variants': [],
#   'english': 'lines on a trigram',
#   'jyutping': 'ngaau4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ngaau4.mp3'},
#  {'stroke_count': 4,
#   'cantonese': '爿',
#   'variants': [],
#   'english': 'half of a tree trunk',
#   'jyutping': 'coeng4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/coeng4.mp3'},
#  {'stroke_count': 4,
#   'cantonese': '片',
#   'variants': [],
#   'english': 'slice',
#   'jyutping': 'pin3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/pin3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/片.gif'},
#  {'stroke_count': 4,
#   'cantonese': '牙',
#   'variants': [],
#   'english': 'tooth',
#   'jyutping': 'ngaa4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ngaa4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/牙.gif'},
#  {'stroke_count': 4,
#   'cantonese': '牛',
#   'variants': ['牜'],
#   'english': 'cow',
#   'jyutping': 'ngau4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ngau4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/牛.gif'},
#  {'stroke_count': 4,
#   'cantonese': '犬',
#   'variants': ['犭'],
#   'english': 'dog',
#   'jyutping': 'hyun2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hyun2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/犬.gif'},
#  {'stroke_count': 5,
#   'cantonese': '玄',
#   'variants': [],
#   'english': 'profound',
#   'jyutping': 'jyun4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyun4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/玄.gif'},
#  {'stroke_count': 5,
#   'cantonese': '玉',
#   'variants': ['王'],
#   'english': 'jade',
#   'jyutping': 'juk6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/juk6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/玉.gif'},
#  {'stroke_count': 5,
#   'cantonese': '瓜',
#   'variants': [],
#   'english': 'melon',
#   'jyutping': 'gwaa1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwaa1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/瓜.gif'},
#  {'stroke_count': 5,
#   'cantonese': '瓦',
#   'variants': [],
#   'english': 'tile',
#   'jyutping': 'ngaa5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ngaa5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/瓦.gif'},
#  {'stroke_count': 5,
#   'cantonese': '甘',
#   'variants': [],
#   'english': 'sweet',
#   'jyutping': 'gam1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gam1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/甘.gif'},
#  {'stroke_count': 5,
#   'cantonese': '生',
#   'variants': [],
#   'english': 'life',
#   'jyutping': 'saang1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/saang1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/生.gif'},
#  {'stroke_count': 5,
#   'cantonese': '用',
#   'variants': [],
#   'english': 'use',
#   'jyutping': 'jung6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jung6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/用.gif'},
#  {'stroke_count': 5,
#   'cantonese': '田',
#   'variants': [],
#   'english': 'field',
#   'jyutping': 'tin4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/tin4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/田.gif'},
#  {'stroke_count': 5,
#   'cantonese': '疋',
#   'variants': [],
#   'english': 'cloth',
#   'jyutping': 'so1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/so1.mp3'},
#  {'stroke_count': 5,
#   'cantonese': '疒',
#   'variants': [],
#   'english': 'ill',
#   'jyutping': 'nik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/nik6.mp3'},
#  {'stroke_count': 5,
#   'cantonese': '癶',
#   'variants': [],
#   'english': 'foot steps',
#   'jyutping': 'but6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/but6.mp3'},
#  {'stroke_count': 5,
#   'cantonese': '白',
#   'variants': [],
#   'english': 'white',
#   'jyutping': 'baak6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/baak6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/白.gif'},
#  {'stroke_count': 5,
#   'cantonese': '皮',
#   'variants': [],
#   'english': 'skin',
#   'jyutping': 'pei4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/pei4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/皮.gif'},
#  {'stroke_count': 5,
#   'cantonese': '皿',
#   'variants': [],
#   'english': 'dish',
#   'jyutping': 'ming5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ming5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/皿.gif'},
#  {'stroke_count': 5,
#   'cantonese': '目',
#   'variants': [],
#   'english': 'eye',
#   'jyutping': 'muk6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/muk6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/目.gif'},
#  {'stroke_count': 5,
#   'cantonese': '矛',
#   'variants': [],
#   'english': 'spear',
#   'jyutping': 'maau4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/maau4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/矛.gif'},
#  {'stroke_count': 5,
#   'cantonese': '矢',
#   'variants': [],
#   'english': 'arrow',
#   'jyutping': 'ci2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ci2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/矢.gif'},
#  {'stroke_count': 5,
#   'cantonese': '石',
#   'variants': [],
#   'english': 'stone',
#   'jyutping': 'sek6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sek6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/石.gif'},
#  {'stroke_count': 5,
#   'cantonese': '示',
#   'variants': ['礻'],
#   'english': 'spirit',
#   'jyutping': 'kei4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/kei4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/示.gif'},
#  {'stroke_count': 5,
#   'cantonese': '禸',
#   'variants': [],
#   'english': 'track',
#   'jyutping': 'jau5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jau5.mp3'},
#  {'stroke_count': 5,
#   'cantonese': '禾',
#   'variants': [],
#   'english': 'grain',
#   'jyutping': 'wo4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wo4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/禾.gif'},
#  {'stroke_count': 5,
#   'cantonese': '穴',
#   'variants': [],
#   'english': 'cave',
#   'jyutping': 'jyut6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyut6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/穴.gif'},
#  {'stroke_count': 5,
#   'cantonese': '立',
#   'variants': [],
#   'english': 'stand',
#   'jyutping': 'laap6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/laap6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/立.gif'},
#  {'stroke_count': 6,
#   'cantonese': '竹',
#   'variants': ['⺮'],
#   'english': 'bamboo',
#   'jyutping': 'zuk1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zuk1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/竹.gif'},
#  {'stroke_count': 6,
#   'cantonese': '米',
#   'variants': [],
#   'english': 'rice',
#   'jyutping': 'mai5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mai5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/米.gif'},
#  {'stroke_count': 6,
#   'cantonese': '糸',
#   'variants': [],
#   'english': 'silk',
#   'jyutping': 'mik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mik6.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '缶',
#   'variants': [],
#   'english': 'jar',
#   'jyutping': 'fau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fau2.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '网',
#   'variants': ['罒'],
#   'english': 'net',
#   'jyutping': 'mong5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mong5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/网.gif'},
#  {'stroke_count': 6,
#   'cantonese': '羊',
#   'variants': [],
#   'english': 'sheep',
#   'jyutping': 'joeng4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/joeng4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/羊.gif'},
#  {'stroke_count': 6,
#   'cantonese': '羽',
#   'variants': [],
#   'english': 'feather',
#   'jyutping': 'jyu5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyu5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/羽.gif'},
#  {'stroke_count': 6,
#   'cantonese': '老',
#   'variants': [],
#   'english': 'old',
#   'jyutping': 'lou5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/lou5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/老.gif'},
#  {'stroke_count': 6,
#   'cantonese': '而',
#   'variants': [],
#   'english': 'and',
#   'jyutping': 'ji6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ji6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/而.gif'},
#  {'stroke_count': 6,
#   'cantonese': '耒',
#   'variants': [],
#   'english': 'plow',
#   'jyutping': 'leoi6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/leoi6.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '耳',
#   'variants': [],
#   'english': 'ear',
#   'jyutping': 'ji5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ji5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/耳.gif'},
#  {'stroke_count': 6,
#   'cantonese': '聿',
#   'variants': [],
#   'english': 'brush',
#   'jyutping': 'wat6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wat6.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '肉',
#   'variants': [],
#   'english': 'meat',
#   'jyutping': 'juk6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/juk6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/肉.gif'},
#  {'stroke_count': 6,
#   'cantonese': '臣',
#   'variants': [],
#   'english': 'minister',
#   'jyutping': 'san4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/san4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/臣.gif'},
#  {'stroke_count': 6,
#   'cantonese': '自',
#   'variants': [],
#   'english': 'oneself',
#   'jyutping': 'zi6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/自.gif'},
#  {'stroke_count': 6,
#   'cantonese': '至',
#   'variants': [],
#   'english': 'arrive',
#   'jyutping': 'zi3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/至.gif'},
#  {'stroke_count': 6,
#   'cantonese': '臼',
#   'variants': [],
#   'english': 'mortar',
#   'jyutping': 'kau5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/kau5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/臼.gif'},
#  {'stroke_count': 6,
#   'cantonese': '舌',
#   'variants': [],
#   'english': 'tongue',
#   'jyutping': 'sik3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sik3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/舌.gif'},
#  {'stroke_count': 6,
#   'cantonese': '舛',
#   'variants': [],
#   'english': 'contrary',
#   'jyutping': 'cyun2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cyun2.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '舟',
#   'variants': [],
#   'english': 'boat',
#   'jyutping': 'zau1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zau1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/舟.gif'},
#  {'stroke_count': 6,
#   'cantonese': '艮',
#   'variants': [],
#   'english': 'mountain',
#   'jyutping': 'gan3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gan3.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '色',
#   'variants': [],
#   'english': 'color',
#   'jyutping': 'sik1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sik1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/色.gif'},
#  {'stroke_count': 6,
#   'cantonese': '艸',
#   'variants': ['艹'],
#   'english': 'grass',
#   'jyutping': 'cou2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cou2.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '虍',
#   'variants': [],
#   'english': 'tiger',
#   'jyutping': 'fu1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fu1.mp3'},
#  {'stroke_count': 6,
#   'cantonese': '虫',
#   'variants': [],
#   'english': 'insect',
#   'jyutping': 'wai2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wai2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/虫.gif'},
#  {'stroke_count': 6,
#   'cantonese': '血',
#   'variants': [],
#   'english': 'blood',
#   'jyutping': 'hyut3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hyut3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/血.gif'},
#  {'stroke_count': 6,
#   'cantonese': '行',
#   'variants': [],
#   'english': 'walk',
#   'jyutping': 'hang4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hang4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/行.gif'},
#  {'stroke_count': 6,
#   'cantonese': '衣',
#   'variants': ['衤'],
#   'english': 'clothes',
#   'jyutping': 'ji1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ji1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/衣.gif'},
#  {'stroke_count': 6,
#   'cantonese': '西',
#   'variants': ['覀'],
#   'english': 'west',
#   'jyutping': 'aa3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/aa3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/西.gif'},
#  {'stroke_count': 7,
#   'cantonese': '見',
#   'variants': [],
#   'english': 'see',
#   'jyutping': 'gin3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gin3.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '角',
#   'variants': [],
#   'english': 'horn',
#   'jyutping': 'gok3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gok3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/角.gif'},
#  {'stroke_count': 7,
#   'cantonese': '言',
#   'variants': [],
#   'english': 'speech',
#   'jyutping': 'jin4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jin4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/言.gif'},
#  {'stroke_count': 7,
#   'cantonese': '谷',
#   'variants': [],
#   'english': 'valley',
#   'jyutping': 'guk1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/guk1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/谷.gif'},
#  {'stroke_count': 7,
#   'cantonese': '豆',
#   'variants': [],
#   'english': 'bean',
#   'jyutping': 'dau6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/dau6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/豆.gif'},
#  {'stroke_count': 7,
#   'cantonese': '豕',
#   'variants': [],
#   'english': 'pig',
#   'jyutping': 'ci2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ci2.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '豸',
#   'variants': [],
#   'english': 'badger',
#   'jyutping': 'zi6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi6.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '貝',
#   'variants': [],
#   'english': 'shell',
#   'jyutping': 'bui3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bui3.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '赤',
#   'variants': [],
#   'english': 'red',
#   'jyutping': 'cek3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cek3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/赤.gif'},
#  {'stroke_count': 7,
#   'cantonese': '走',
#   'variants': [],
#   'english': 'walk',
#   'jyutping': 'zau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/走.gif'},
#  {'stroke_count': 7,
#   'cantonese': '足',
#   'variants': [],
#   'english': 'foot',
#   'jyutping': 'zuk1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zuk1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/足.gif'},
#  {'stroke_count': 7,
#   'cantonese': '身',
#   'variants': [],
#   'english': 'body',
#   'jyutping': 'san1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/san1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/身.gif'},
#  {'stroke_count': 7,
#   'cantonese': '車',
#   'variants': [],
#   'english': 'cart',
#   'jyutping': 'ce1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ce1.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '辛',
#   'variants': [],
#   'english': 'bitter',
#   'jyutping': 'san1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/san1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/辛.gif'},
#  {'stroke_count': 7,
#   'cantonese': '辰',
#   'variants': [],
#   'english': 'morning',
#   'jyutping': 'san4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/san4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/辰.gif'},
#  {'stroke_count': 7,
#   'cantonese': '辵',
#   'variants': ['辶'],
#   'english': 'walk',
#   'jyutping': 'coek3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/coek3.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '邑',
#   'variants': ['阝',
#    '(',
#    'o',
#    'n',
#    'r',
#    'i',
#    'g',
#    'h',
#    't',
#    's',
#    'i',
#    'd',
#    'e',
#    ')'],
#   'english': 'city',
#   'jyutping': 'jap1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jap1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/邑.gif'},
#  {'stroke_count': 7,
#   'cantonese': '酉',
#   'variants': [],
#   'english': 'wine',
#   'jyutping': 'jau5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jau5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/酉.gif'},
#  {'stroke_count': 7,
#   'cantonese': '釆',
#   'variants': [],
#   'english': 'distinguish',
#   'jyutping': 'bin6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bin6.mp3'},
#  {'stroke_count': 7,
#   'cantonese': '里',
#   'variants': [],
#   'english': 'village',
#   'jyutping': 'bin6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bin6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/里.gif'},
#  {'stroke_count': 8,
#   'cantonese': '金',
#   'variants': [],
#   'english': 'metal',
#   'jyutping': 'gam1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gam1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/金.gif'},
#  {'stroke_count': 8,
#   'cantonese': '長',
#   'variants': [],
#   'english': 'long',
#   'jyutping': 'coeng4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/coeng4.mp3'},
#  {'stroke_count': 8,
#   'cantonese': '門',
#   'variants': [],
#   'english': 'gate',
#   'jyutping': 'mun4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mun4.mp3'},
#  {'stroke_count': 8,
#   'cantonese': '阜',
#   'variants': [],
#   'english': 'mound',
#   'jyutping': 'fau6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fau6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/阜.gif'},
#  {'stroke_count': 8,
#   'cantonese': '隶',
#   'variants': [],
#   'english': 'slave',
#   'jyutping': 'dai6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/dai6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/隶.gif'},
#  {'stroke_count': 8,
#   'cantonese': '隹',
#   'variants': [],
#   'english': 'short-tailed bird',
#   'jyutping': 'zeoi1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zeoi1.mp3'},
#  {'stroke_count': 8,
#   'cantonese': '雨',
#   'variants': [],
#   'english': 'rain',
#   'jyutping': 'jyu5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyu5.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/雨.gif'},
#  {'stroke_count': 8,
#   'cantonese': '青',
#   'variants': [],
#   'english': 'blue',
#   'jyutping': 'cing1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cing1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/青.gif'},
#  {'stroke_count': 8,
#   'cantonese': '非',
#   'variants': [],
#   'english': 'wrong',
#   'jyutping': 'fei1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fei1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/非.gif'},
#  {'stroke_count': 9,
#   'cantonese': '面',
#   'variants': [],
#   'english': 'face',
#   'jyutping': 'min6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/min6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/面.gif'},
#  {'stroke_count': 9,
#   'cantonese': '革',
#   'variants': [],
#   'english': 'leather',
#   'jyutping': 'gaak3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gaak3.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/革.gif'},
#  {'stroke_count': 9,
#   'cantonese': '韋',
#   'variants': [],
#   'english': 'soft leather',
#   'jyutping': 'wai5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wai5.mp3'},
#  {'stroke_count': 9,
#   'cantonese': '韭',
#   'variants': [],
#   'english': 'leek',
#   'jyutping': 'gau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/韭.gif'},
#  {'stroke_count': 9,
#   'cantonese': '音',
#   'variants': [],
#   'english': 'sound',
#   'jyutping': 'jam1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jam1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/音.gif'},
#  {'stroke_count': 9,
#   'cantonese': '頁',
#   'variants': [],
#   'english': 'page',
#   'jyutping': 'jip6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jip6.mp3'},
#  {'stroke_count': 9,
#   'cantonese': '風',
#   'variants': [],
#   'english': 'wind',
#   'jyutping': 'fung1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fung1.mp3'},
#  {'stroke_count': 9,
#   'cantonese': '飛',
#   'variants': [],
#   'english': 'fly',
#   'jyutping': 'fei1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/fei1.mp3'},
#  {'stroke_count': 9,
#   'cantonese': '食',
#   'variants': ['飠'],
#   'english': 'eat',
#   'jyutping': 'sik6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sik6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/食.gif'},
#  {'stroke_count': 9,
#   'cantonese': '首',
#   'variants': [],
#   'english': 'head',
#   'jyutping': 'sau2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/sau2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/首.gif'},
#  {'stroke_count': 9,
#   'cantonese': '香',
#   'variants': [],
#   'english': 'fragrant',
#   'jyutping': 'hoeng1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hoeng1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/香.gif'},
#  {'stroke_count': 9,
#   'cantonese': '馬',
#   'variants': [],
#   'english': 'horse',
#   'jyutping': 'maa5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/maa5.mp3'},
#  {'stroke_count': 9,
#   'cantonese': '骨',
#   'variants': [],
#   'english': 'bone',
#   'jyutping': 'gwat1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwat1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/骨.gif'},
#  {'stroke_count': 10,
#   'cantonese': '高',
#   'variants': [],
#   'english': 'high',
#   'jyutping': 'gou1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gou1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/高.gif'},
#  {'stroke_count': 10,
#   'cantonese': '髟',
#   'variants': [],
#   'english': 'long hair',
#   'jyutping': 'biu1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/biu1.mp3'},
#  {'stroke_count': 10,
#   'cantonese': '鬥',
#   'variants': [],
#   'english': 'fight',
#   'jyutping': 'dau3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/dau3.mp3'},
#  {'stroke_count': 10,
#   'cantonese': '鬯',
#   'variants': [],
#   'english': 'sacrificial wine',
#   'jyutping': 'coeng3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/coeng3.mp3'},
#  {'stroke_count': 10,
#   'cantonese': '鬲',
#   'variants': [],
#   'english': 'cauldron',
#   'jyutping': 'gaak3',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gaak3.mp3'},
#  {'stroke_count': 10,
#   'cantonese': '鬼',
#   'variants': [],
#   'english': 'ghost',
#   'jyutping': 'gwai2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwai2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鬼.gif'},
#  {'stroke_count': 11,
#   'cantonese': '魚',
#   'variants': [],
#   'english': 'fish',
#   'jyutping': 'jyu4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/jyu4.mp3'},
#  {'stroke_count': 11,
#   'cantonese': '鳥',
#   'variants': [],
#   'english': 'bird',
#   'jyutping': 'niu5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/niu5.mp3'},
#  {'stroke_count': 11,
#   'cantonese': '鹵',
#   'variants': [],
#   'english': 'salty',
#   'jyutping': 'lou5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/lou5.mp3'},
#  {'stroke_count': 11,
#   'cantonese': '鹿',
#   'variants': [],
#   'english': 'deer',
#   'jyutping': 'luk6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/luk6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鹿.gif'},
#  {'stroke_count': 11,
#   'cantonese': '麥',
#   'variants': [],
#   'english': 'wheat',
#   'jyutping': 'mak6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/mak6.mp3'},
#  {'stroke_count': 11,
#   'cantonese': '麻',
#   'variants': [],
#   'english': 'hemp',
#   'jyutping': 'maa4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/maa4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/麻.gif'},
#  {'stroke_count': 11,
#   'cantonese': '黄',
#   'variants': [],
#   'english': 'yellow',
#   'jyutping': 'wong4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/wong4.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/黄.gif'},
#  {'stroke_count': 12,
#   'cantonese': '黍',
#   'variants': [],
#   'english': 'millet',
#   'jyutping': 'syu2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/syu2.mp3'},
#  {'stroke_count': 12,
#   'cantonese': '黑',
#   'variants': [],
#   'english': 'black',
#   'jyutping': 'hak1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/hak1.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/黑.gif'},
#  {'stroke_count': 12,
#   'cantonese': '黹',
#   'variants': [],
#   'english': 'embroidery',
#   'jyutping': 'zi2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/zi2.mp3'},
#  {'stroke_count': 12,
#   'cantonese': '黽',
#   'variants': [],
#   'english': 'frog',
#   'jyutping': 'maang5',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/maang5.mp3'},
#  {'stroke_count': 12,
#   'cantonese': '鼎',
#   'variants': [],
#   'english': 'tripod',
#   'jyutping': 'ding2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ding2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鼎.gif'},
#  {'stroke_count': 13,
#   'cantonese': '鼓',
#   'variants': [],
#   'english': 'drum',
#   'jyutping': 'gu2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gu2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鼓.gif'},
#  {'stroke_count': 13,
#   'cantonese': '鼠',
#   'variants': [],
#   'english': 'rat',
#   'jyutping': 'syu2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/syu2.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鼠.gif'},
#  {'stroke_count': 14,
#   'cantonese': '鼻',
#   'variants': [],
#   'english': 'nose',
#   'jyutping': 'bei6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/bei6.mp3',
#   'strokes_path': '../data/cantonese/strokeGifs/鼻.gif'},
#  {'stroke_count': 14,
#   'cantonese': '齊',
#   'variants': [],
#   'english': 'even',
#   'jyutping': 'cai4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/cai4.mp3'},
#  {'stroke_count': 15,
#   'cantonese': '齒',
#   'variants': [],
#   'english': 'tooth',
#   'jyutping': 'ci2',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/ci2.mp3'},
#  {'stroke_count': 16,
#   'cantonese': '龍',
#   'variants': [],
#   'english': 'dragon',
#   'jyutping': 'lung4',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/lung4.mp3'},
#  {'stroke_count': 16,
#   'cantonese': '龜',
#   'variants': [],
#   'english': 'turtle',
#   'jyutping': 'gwai1',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/gwai1.mp3'},
#  {'stroke_count': 17,
#   'cantonese': '龠',
#   'variants': [],
#   'english': 'flute',
#   'jyutping': 'joek6',
#   'audio_path': '/home/alex/projects/ltt/data/data/cantonese/pronunciationMp3s/joek6.mp3'}]

# %%
# collect mp3 files
# https://www.cantonesetools.org/en/cantonese-text-to-sound
# paths need to be full to work with anki
PATH_TO_MP3_URLS = "/home/alex/projects/ltt/data/cantonese/mp3Urls.json"
PATH_TO_MP3S = "/home/alex/projects/ltt/data/cantonese/pronunciationMp3s"
mp3_urls_dict = json.load(open(PATH_TO_MP3_URLS))

for entry in radical_data:
    if entry['jyutping'] in mp3_urls_dict:
        url = mp3_urls_dict[entry["jyutping"]]
        output_path = f'{PATH_TO_MP3S}/{entry["jyutping"]}.mp3'
#         !curl '{url}' --output '{output_path}' && sleep 1
        entry['audio_path'] = output_path
        
# TODO this produces 180 mp3s, not 214?

# %%
# collect stroke order gifs
# http://www.strokeorder.info/
PATH_TO_STROKE_GIFS = '/home/alex/projects/ltt/data/cantonese/strokeGifs'
url_template = "http://www.strokeorder.info/mandarin.php?q={}"

for entry in radical_data:
    try:
        # !sleep 1 #throttle
        page_content = requests.get(url_template.format(entry['cantonese'])).content
        soup = BeautifulSoup(page_content, 'html.parser')
        stroke_data = list(filter(lambda x: x.has_attr('src') and '.gif' in x['src'], soup.find_all('img')))[0]

        url = stroke_data['src']
        output_path = f'{PATH_TO_STROKE_GIFS}/{entry["cantonese"]}.gif'
#         !curl '{url}' --output '{output_path}' && sleep 1
        entry['strokes_path'] = output_path
    except:
        print('failed to get stroke gif for ' + entry['cantonese'])
# Out:
# failed to get stroke gif for 丨
# failed to get stroke gif for 丶
# failed to get stroke gif for 丿
# failed to get stroke gif for 亅
# failed to get stroke gif for 亠
# failed to get stroke gif for 亻
# failed to get stroke gif for 冂
# failed to get stroke gif for 冖
# failed to get stroke gif for 冫
# failed to get stroke gif for 凵
# failed to get stroke gif for 勹
# failed to get stroke gif for 匚
# failed to get stroke gif for 匸
# failed to get stroke gif for 卩
# failed to get stroke gif for 厶
# failed to get stroke gif for 囗
# failed to get stroke gif for 夂
# failed to get stroke gif for 夊
# failed to get stroke gif for 宀
# failed to get stroke gif for 尢
# failed to get stroke gif for 屮
# failed to get stroke gif for 巛
# failed to get stroke gif for 廴
# failed to get stroke gif for 廾
# failed to get stroke gif for 彐
# failed to get stroke gif for 彡
# failed to get stroke gif for 彳
# failed to get stroke gif for 攴
# failed to get stroke gif for 殳
# failed to get stroke gif for 爻
# failed to get stroke gif for 爿
# failed to get stroke gif for 疋
# failed to get stroke gif for 疒
# failed to get stroke gif for 癶
# failed to get stroke gif for 禸
# failed to get stroke gif for 糸
# failed to get stroke gif for 缶
# failed to get stroke gif for 耒
# failed to get stroke gif for 聿
# failed to get stroke gif for 舛
# failed to get stroke gif for 艮
# failed to get stroke gif for 艸
# failed to get stroke gif for 虍
# failed to get stroke gif for 見
# failed to get stroke gif for 豕
# failed to get stroke gif for 豸
# failed to get stroke gif for 貝
# failed to get stroke gif for 車
# failed to get stroke gif for 辵
# failed to get stroke gif for 釆
# failed to get stroke gif for 長
# failed to get stroke gif for 門
# failed to get stroke gif for 隹
# failed to get stroke gif for 韋
# failed to get stroke gif for 頁
# failed to get stroke gif for 風
# failed to get stroke gif for 飛
# failed to get stroke gif for 馬
# failed to get stroke gif for 髟
# failed to get stroke gif for 鬥
# failed to get stroke gif for 鬯
# failed to get stroke gif for 鬲
# failed to get stroke gif for 魚
# failed to get stroke gif for 鳥
# failed to get stroke gif for 鹵
# failed to get stroke gif for 麥
# failed to get stroke gif for 黍
# failed to get stroke gif for 黹
# failed to get stroke gif for 黽
# failed to get stroke gif for 齊
# failed to get stroke gif for 齒
# failed to get stroke gif for 龍
# failed to get stroke gif for 龜
# failed to get stroke gif for 龠

# %%
def invoke(payload):
    requestJson = json.dumps(payload).encode('utf-8')
    response = json.load(urllib.request.urlopen(urllib.request.Request('http://localhost:8765', requestJson)))
    return response

# %%
# https://foosoft.net/projects/anki-connect/#card-actions
import json
import urllib.request
from os.path import basename

for entry in radical_data:
    character = entry['cantonese']
    romanization = entry['jyutping']
    english = entry['english']
    payload = {
        "action": "addNote",
        "version": "6",
        "params": {
            "note": {
                "deckName": "Chinese::Vocab",
                "modelName": "Chinese",
                "fields": {
                    "character": character,
                    "romanization": romanization,
                    "english": english
                }
            }
        }
    }
    
    if 'audio_path' in entry:
        audio = entry['audio_path']
        payload['params']['note']['audio'] = [{
            "filename": f"cantonese/audio/{basename(audio)}",
            "path": audio,
            "fields": [
                "audio"
        ]}]
        
    if 'strokes_path' in entry:
        strokes = entry['strokes_path']
        payload['params']['note']['picture'] =  [{
                    "filename": f"cantonese/strokes/{basename(strokes)}",
                    "path": strokes,
                    "fields": [
                        "strokes"
        ]}]
        
    invoke(payload)
    # !sleep 1
