# %%
from query import query_character
from search_results_scraping import get_search_results_tables

# %%
results_soup = query_character('己')

# %%
get_search_results_tables(results_soup)
# Out:
# [<table align="center" cellpadding="0" cellspacing="0" class="border valign" width="95%">
#  <tr>
#  <td colspan="5">
#  <b>Found 63 word entries for "己"</b>
#  <br/><small>Link to this search: <a href="http://www.cantonese.sheik.co.uk/dictionary/search/?searchtype=1&amp;text=%E5%B7%B1">http://www.cantonese.sheik.co.uk/dictionary/search/?searchtype=1&amp;text=%E5%B7%B1</a> </small></td>
#  </tr>
#  <tr><td colspan="5"></td>
#  </tr>
#  <tr><td width="3%"></td><td width="22%"><b>Word</b></td><td width="18%"><b>jyutping</b></td><td width="18%"><b>pinyin</b></td><td width="*"><b>Meaning</b></td></tr>
#  <tr>
#  <td><a href="http://www.cantonese.sheik.co.uk/dictionary/words/835/"><img align="absmiddle" alt="desc" border="0" hspace="2" src="http://www.cantonese.sheik.co.uk/images/icons/book.gif" vspace="3"/>
#  </a></td>
# ...
